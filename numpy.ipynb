# %%
list=['1',2,3,4,5]
for i in list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
import numpy

# %%
arr=numpy.array([1,2,3,4])

# %%
print(arr)
# Out:
# [1 2 3 4]

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
arr = numpy.array([[[5,6]], [[7,8]]])
print(arr[0,0,0])
# Out:
# 5

# %%
arr = numpy.array([[[5,6,5,6]], [[7,8,7,8]]])
print(arr[0,0,3:-3:-1])
print(arr.ndim)
# Out:
# [6 5]
# 3

# %%
arr=numpy.array([1,2,3,4,8,9,0,8,1,2,3,4,8,9,0,8])
arr.reshape(2,2,2,2)
# Out:
# array([[[[1, 2],
#          [3, 4]],
#
#         [[8, 9],
#          [0, 8]]],
#
#
#        [[[1, 2],
#          [3, 4]],
#
#         [[8, 9],
#          [0, 8]]]])

# %%
arr = numpy.array([[[5,6,5,6]], [[7,8,7,8]]])
arr.reshape(-1)
# Out:
# array([5, 6, 5, 6, 7, 8, 7, 8])

# %%
import numpy as np
arr1 = numpy.array([
    [1,2],
    [3,4]
])
arr2 = numpy.array([
    [5,6],
    [7,8]
])

# %%
output = numpy.concatenate((arr1,arr2),axis=1)
print(output, output.shape)
# Out:
# [[1 2 5 6]
#  [3 4 7 8]] (2, 4)

# %%
print(np.stack((arr1,arr2),axis=0))
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]

# %%
arr=numpy.array([[1,2,3,4],[5,6,7,8]])
index=np.searchsorted(arr,[6,1,2,3],'right')
print(index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 arr=numpy.array([[1,2,3,4],[5,6,7,8]])
# ----> 2 index=np.searchsorted(arr,[6,1,2,3],'right')
#       3 print(index)
#
# File c:\Users\TECHNIFI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\_core\fromnumeric.py:1501, in searchsorted(a, v, side, sorter)
#    1421 @array_function_dispatch(_searchsorted_dispatcher)
#    1422 def searchsorted(a, v, side='left', sorter=None):
#    1423     """
#    1424     Find indices where elements should be inserted to maintain order.
#    1425
#    (...)   1499     30  # The element at index 2 of the sorted array is 30.
#    1500     """
# -> 1501     return _wrapfunc(a, 'searchsorted', v, side=side, sorter=sorter)
#
# ...
