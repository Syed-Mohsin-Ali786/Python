# %%
import matplotlib.pyplot as pyplot
import pandas as pd
import seaborn as sns
df= pd.read_csv("salaries_and_fields_cleaned.csv")
df.head()
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.14.4' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.info()
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.14.4' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.describe()

# %%
df.isna().sum()

# %%
df["Employment_Status"].value().count()

# %%
df.groupby("Experience").mean(numeric_only=True)

# %%
df.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)

# %%
sns.boxplot(df,x="Experience",y="Salary_usd")
plt.yscale("log")
plt.show()
