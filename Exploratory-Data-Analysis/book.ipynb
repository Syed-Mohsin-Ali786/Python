# %%
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns

# %%
df=pd.read_csv("clean_books.csv")
df.head()
# Out:
#                                                 name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      author  rating  year        genre
# 0                  JJ Smith     4.7  2016  Non Fiction
# 1              Stephen King     4.6  2011      Fiction
# 2        Jordan B. Peterson     4.7  2018  Non Fiction
# 3             George Orwell     4.7  2017      Fiction
# 4  National Geographic Kids     4.8  2019    Childrens

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    350 non-null    str
#  1   author  350 non-null    str
#  2   rating  350 non-null    float64
#  3   year    350 non-null    int64
#  4   genre   350 non-null    str
# dtypes: float64(1), int64(1), str(3)
# memory usage: 13.8 KB

# %%
df.describe()
# Out:
#            rating         year
# count  350.000000   350.000000
# mean     4.608571  2013.508571
# std      0.226941     3.284711
# min      3.300000  2009.000000
# 25%      4.500000  2010.000000
# 50%      4.600000  2013.000000
# 75%      4.800000  2016.000000
# max      4.900000  2019.000000

# %%
df.isna().sum()
# Out:
# name      0
# author    0
# rating    0
# year      0
# genre     0
# dtype: int64

# %%
df.duplicated().count()
# Out:
# np.int64(350)

# %%
df["genre"].value_counts()
# Out:
# genre
# Non Fiction    179
# Fiction        131
# Childrens       40
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5.3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.figure(figsize=5.3)
#
# File c:\Users\TECHNIFI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\matplotlib\pyplot.py:1041, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1031 if len(allnums) == max_open_warning >= 1:
#    1032     _api.warn_external(
#    1033         f"More than {max_open_warning} figures have been opened. "
#    1034         f"Figures created through the pyplot interface "
#    (...)   1038         f"Consider using `matplotlib.pyplot.close()`.",
#    1039         RuntimeWarning)
# -> 1041 manager = new_figure_manager(
#    1042     num, figsize=figsize, dpi=dpi,
#    1043     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#    1044     FigureClass=FigureClass, **kwargs)
#    1045 fig = manager.canvas.figure
# ...

# %%
df[df["genre"]=="Fiction"].head()
# Out:
#                                                 name               author  \
# 1                                  11/22/63: A Novel         Stephen King
# 3                             1984 (Signet Classics)        George Orwell
# 5      A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6  A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 7                     A Gentleman in Moscow: A Novel          Amor Towles
#
#    rating  year    genre
# 1     4.6  2011  Fiction
# 3     4.7  2017  Fiction
# 5     4.4  2011  Fiction
# 6     4.7  2014  Fiction
# 7     4.7  2017  Fiction

# %%
# df[df["genre"].isin(["Fiction"])].head()
df[~df["genre"].isin(["Fiction"])].head()
# Out:
#                                                  name  \
# 0                       10-Day Green Smoothie Cleanse
# 2             12 Rules for Life: An Antidote to Chaos
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 10  A Patriot's History of the United States: From...
#
#                       author  rating  year        genre
# 0                   JJ Smith     4.7  2016  Non Fiction
# 2         Jordan B. Peterson     4.7  2018  Non Fiction
# 4   National Geographic Kids     4.8  2019    Childrens
# 8                James Comey     4.7  2018  Non Fiction
# 10          Larry Schweikart     4.6  2010  Non Fiction

# %%
df.dtypes
# Out:
# name          str
# author        str
# rating    float64
# year        int64
# genre         str
# dtype: object

# %%
# df.select_dtypes("number").head()
# df.select_dtypes("number").mean()
# df.select_dtypes("string").head()
df.select_dtypes("string")[["author","genre"]].mode()
# Out:
#         author        genre
# 0  Jeff Kinney  Non Fiction

# %%
df.select_dtypes('number').agg(["mean","median"])
# Out:
#           rating         year
# mean    4.608571  2013.508571
# median  4.600000  2013.000000

# %%
sns.boxplot(df,x="rating")
plt.show()

# %%
sns.histplot(df,x="rating")
